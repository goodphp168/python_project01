# %% [markdown]
# <a href="https://colab.research.google.com/github/roberthsu2003/__2026_05_09_chihlee_python__/blob/main/05_09/2026_05_09_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello! Python!")
# Out:
# Hello! Python!

# %% [markdown]
# ### 這是第一節上課的講義
# 下面是數學運算的介紹
#
# 先介紹*變數*,**數學運算子**
#
# #### 專有名詞介紹
#
# - 變數
# - 數學運算子
#
# 1. 運算子,運算元
# 2. 運算式,敘述式

# %%
print("這是整數", 5, "\n", "這是浮點數", 5.0, "\n", "這是字串", "5.0")
# Out:
# 這是整數 5
#  這是浮點數 5.0
#  這是字串 5.0
